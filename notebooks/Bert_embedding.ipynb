# %%
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd

from pathlib import Path

from transformers import BertTokenizer, BertModel, BertForMaskedLM
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-german-cased')
# model = BertModel.from_pretrained('bert-base-german-cased')
model = BertForMaskedLM.from_pretrained('bert-base-german-cased')

file_path = Path("..") / "data" / "Cajal.txt" / "inception-document2176491558147248257" / "CURATION_USER.xmi"


tree = ET.parse(file_path)
root = tree.getroot()

# namespace dictionary
namespaces = {
    'xmi': 'http://www.omg.org/XMI',
    'cas': 'http:///uima/cas.ecore',
    'custom': 'http:///webanno/custom.ecore',
    'type5': 'http:///de/tudarmstadt/ukp/dkpro/core/api/segmentation/type.ecore'}

# data extraction
sofa = root.find('.//cas:Sofa', namespaces)        #  './' means "search from the current node".'//' means "search all descendants, not just immediate children". './/cas:Sofa' means "find any descendant element named 'Sofa' in the 'cas' namespace, starting from the current node".
text_content = sofa.get('sofaString')
root = tree.getroot()
sentences = root.findall('.//type5:Sentence', namespaces)
words = root.findall('.//type5:Token', namespaces)
PII_annotations = root.findall('.//custom:PHI', namespaces)

# used for finding a decent context window
sentence_info = []
for sentence in sentences:
    start = int(sentence.get('begin'))
    end = int(sentence.get('end'))
    sentence_text = text_content[start:end]
    # Tokenize 
    tokens = tokenizer(sentence_text, padding=False, truncation=False, return_tensors='pt')
    # Get the number of tokens
    token_count = tokens.input_ids.shape[1]
    
    sentence_info.append((start, end, token_count))
# Out:
# Some weights of the model checkpoint at bert-base-german-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Bert can only process 512 tokens so we need to define a context window for the annoations
def find_context_window(word_start, sentence_info, max_tokens=512):
    # Find the sentence containing the word
    containing_sentence = next((s for s in sentence_info if s[0] <= word_start < s[1]), None)

    # Initialize the context with the containing sentence
    context_start = containing_sentence[0]
    context_end = containing_sentence[1]
    token_count = containing_sentence[2]
    
    left_index = right_index = sentence_info.index(containing_sentence)
    
    while token_count < max_tokens:
        # Try to add a sentence to the left
        if left_index > 0:
            left_sentence = sentence_info[left_index - 1]
            if token_count + left_sentence[2] <= max_tokens:
                context_start = left_sentence[0]
                token_count += left_sentence[2]
                left_index -= 1
            else:
                break
        
        # Try to add a sentence to the right
        if right_index < len(sentence_info) - 1:
            right_sentence = sentence_info[right_index + 1]
            if token_count + right_sentence[2] <= max_tokens:
                context_end = right_sentence[1]
                token_count += right_sentence[2]
                right_index += 1
            else:
                break 
        
        # can't add to either side
        if left_index == 0 and right_index == len(sentence_info) - 1:
            break

    return context_start, context_end

# %%
# word processing
PII_data = []
for PII_annotation in PII_annotations:
    PII_start = int(PII_annotation.get('begin'))
    PII_end = int(PII_annotation.get('end'))
    context_start, context_end = find_context_window(PII_start,sentence_info)
    PII_data.append({
        'PII_entity': text_content[PII_start:PII_end],
        'PII_category': PII_annotation.get('kind'),
        'PII_start': PII_start,
        'PII_end': PII_end,
        'bert_context_start': int(context_start),
        'bert_context_end': int(context_end)
        
    })
       
PII_df = pd.DataFrame(PII_data)        
PII_df['PII_tokenized'] = [None] * len(PII_df)
PII_df['Token_embeddings'] = [None] * len(PII_df)
PII_df['Token_mean_embedding'] = [None] * len(PII_df)

tokens_list = []
for _ , PII in PII_df.iterrows():
    tokens = tokenizer(PII['PII_entity'], add_special_tokens=False)
    # Convert the tensor to a list
    tokens_list.append(tokens['input_ids'])
    
PII_df['PII_tokenized'] = tokens_list

# %% [markdown]
# ## Base Bert Model

# %%
PII_token_data = []

for _, PII in PII_df.iterrows():
    chunk = text_content[PII['bert_context_start']:PII['bert_context_end']]
    
    # Tokenize the entire chunk
    encoded_chunk = tokenizer(chunk, padding=True, truncation=True, return_tensors='pt')
    
    # Get embeddings
    with torch.no_grad():
        outputs = model(**encoded_chunk)
    chunk_embeddings = outputs.last_hidden_state[0]  # Remove batch dimension
    chunk_tokens = encoded_chunk['input_ids'][0].tolist()  # Get integer token IDs
    
    PII_start_index = None
    for i in range(len(chunk_tokens) - len(PII['PII_tokenized']) + 1):
        if chunk_tokens[i:i+len(PII['PII_tokenized'])] == PII['PII_tokenized']:
            PII_start_index = i
            break
    
    if PII_start_index is not None:
        PII_tokenized = chunk_tokens[PII_start_index:PII_start_index+len(PII['PII_tokenized'])]
        PII_embeddings = np.array(chunk_embeddings[PII_start_index:PII_start_index+len(PII['PII_tokenized'])])#.tolist()
        
        PII_token_data.append({
            'PII_entity': PII['PII_entity'],
            'PII_tokenized': PII_tokenized,
            'Token_embeddings': PII_embeddings
        })

# Create the new DataFrame
PII_token_df = pd.DataFrame(PII_token_data)

PII_df['Token_embeddings'] = PII_token_df['Token_embeddings']

PII_df['Token_mean_embedding'] = PII_df['Token_embeddings'].apply(lambda x: np.mean(x, axis=0)) #.apply() is a pandas method that applies a function to each element of the Series
PII_df

# %% [markdown]
# ## Masked Bert Model

# %%
PII_token_data = []

for _, PII in PII_df.iterrows():
    chunk = text_content[PII['bert_context_start']:PII['bert_context_end']]
    
    # Tokenize the entire chunk
    encoded_chunk = tokenizer(chunk, padding=True, truncation=True, return_tensors='pt')
    
    # Get embeddings
    with torch.no_grad():
        outputs = model(**encoded_chunk, output_hidden_states = True)
        
    chunk_embeddings = outputs.hidden_states[-1][0]  # Remove batch dimension
    chunk_tokens = encoded_chunk['input_ids'][0].tolist()  # Get integer token IDs
    
    # # predict top tokens for each token masked or not
    logits = outputs.logits
    # Get predictions for all tokens
    for i, token_id in enumerate(encoded_chunk['input_ids'][0]):
        token_logits = logits[0, i, :]
        top_5_tokens = torch.topk(token_logits, 5, dim=0).indices.tolist()
        print(f"Original token: {tokenizer.decode([token_id])}")
        print("Top 5 predictions:")
        for token in top_5_tokens:
            print(f"- {tokenizer.decode([token])}")
        print()
    
    PII_start_index = None
    for i in range(len(chunk_tokens) - len(PII['PII_tokenized']) + 1):
        if chunk_tokens[i:i+len(PII['PII_tokenized'])] == PII['PII_tokenized']:
            PII_start_index = i
            break
    
    if PII_start_index is not None:
        PII_tokenized = chunk_tokens[PII_start_index:PII_start_index+len(PII['PII_tokenized'])]
        PII_embeddings = np.array(chunk_embeddings[PII_start_index:PII_start_index+len(PII['PII_tokenized'])])#.tolist()
        
        PII_token_data.append({
            'PII_entity': PII['PII_entity'],
            'PII_tokenized': PII_tokenized,
            'Token_embeddings': PII_embeddings
        })

# Create the new DataFrame
PII_token_df = pd.DataFrame(PII_token_data)

PII_df['Token_embeddings'] = PII_token_df['Token_embeddings']

PII_df['Token_mean_embedding'] = PII_df['Token_embeddings'].apply(lambda x: np.mean(x, axis=0)) #.apply() is a pandas method that applies a function to each element of the Series
PII_df
# Out:
# Original token: [CLS]
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [UNK]
# - und
# - [unused_punctuation4]
#
# Original token: Di
# Top 5 predictions:
# - Di
# - di
# - Hil
# - Ka
# - ##Di
#
# Original token: ##akon
# Top 5 predictions:
# - ##akon
# - ##af
# - ##arm
# - ##äd
# - ##äst
#
# Original token: ##issen
# Top 5 predictions:
# - ##issen
# - ##ie
# - ##ies
# - ##ien
# - ##ischen
#
# Original token: ##kran
# Top 5 predictions:
# - ##kran
# - ##haus
# - ##ken
# - Kranken
# - ##ke
#
# Original token: ##ken
# Top 5 predictions:
# - ##ken
# - ##ke
# - ##k
# - ##en
# - ##ks
#
# Original token: ##haus
# Top 5 predictions:
# - ##haus
# - ##hauses
# - Haus
# - ##ie
# - ##ke
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##n
# - Deutschland
# - Berliner
# - ##s
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation2]
# - das
# - [unused_punctuation0]
# - [unused_punctuation1]
#
# Original token: Op
# Top 5 predictions:
# - Op
# - In
# - Ne
# - Hyp
# - Di
#
# Original token: ##ht
# Top 5 predictions:
# - ##ht
# - ##ist
# - ##ho
# - ##ät
# - ##hen
#
# Original token: ##hal
# Top 5 predictions:
# - ##hal
# - ##hy
# - ##ho
# - ##her
# - ##hom
#
# Original token: ##mol
# Top 5 predictions:
# - ##mol
# - ##kol
# - ##och
# - ##iol
# - ##men
#
# Original token: ##og
# Top 5 predictions:
# - ##og
# - ##log
# - ##och
# - ##ph
# - ##ut
#
# Original token: ##isches
# Top 5 predictions:
# - ##isches
# - ##isch
# - ##ische
# - ##liches
# - ##ischen
#
# Original token: Zentrum
# Top 5 predictions:
# - Zentrum
# - Institut
# - Krankenhaus
# - ##zentrum
# - Haus
#
# Original token: Di
# Top 5 predictions:
# - Di
# - di
# - Hil
# - ##Di
# - ##di
#
# Original token: ##akon
# Top 5 predictions:
# - ##akon
# - ##af
# - ##vert
# - ##urg
# - ##ich
#
# Original token: ##issen
# Top 5 predictions:
# - ##issen
# - ##ie
# - ##ies
# - ##ien
# - ##ischen
#
# Original token: ##kran
# Top 5 predictions:
# - ##kran
# - ##haus
# - ##ken
# - Kranken
# - ##fach
#
# Original token: ##ken
# Top 5 predictions:
# - ##ken
# - ##ke
# - ##en
# - Kranken
# - ##k
#
# Original token: ##haus
# Top 5 predictions:
# - ##haus
# - ##hauses
# - ##hof
# - Haus
# - ##amt
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - Deutschland
# - ##n
# - Köln
# - ##Berlin
#
# Original token: 122
# Top 5 predictions:
# - 122
# - 12
# - 123
# - 21
# - 120
#
# Original token: ##99
# Top 5 predictions:
# - ##99
# - ##97
# - ##98
# - ##79
# - ##19
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##Berlin
# - Berliner
# - durch
# - Potsdam
#
# Original token: Herrn
# Top 5 predictions:
# - Herrn
# - Herr
# - Den
# - Frau
# - ##Herr
#
# Original token: Dr
# Top 5 predictions:
# - Dr
# - Prof
# - ##Dr
# - Professor
# - Herr
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [UNK]
# - [unused_punctuation2]
# - ##n
# - ##äger
#
# Original token: med
# Top 5 predictions:
# - med
# - Dr
# - Med
# - g
# - jur
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##ias
# - ##icus
# - [UNK]
# - ##ia
#
# Original token: Mike
# Top 5 predictions:
# - Mike
# - Michael
# - Kay
# - Gerald
# - Frank
#
# Original token: Marsch
# Top 5 predictions:
# - Marsch
# - Kl
# - Kn
# - Rad
# - Reg
#
# Original token: ##olle
# Top 5 predictions:
# - ##olle
# - ##ole
# - ##alle
# - ##ale
# - ##one
#
# Original token: ##k
# Top 5 predictions:
# - ##k
# - ##ck
# - ##ke
# - ##n
# - ##ks
#
# Original token: Kant
# Top 5 predictions:
# - Kant
# - Allee
# - Kurfürsten
# - Schön
# - Damm
#
# Original token: ##straße
# Top 5 predictions:
# - ##straße
# - ##str
# - ##allee
# - [unused_punctuation2]
# - ##gasse
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - B
# - Straße
# - 21
# - 0
#
# Original token: 21
# Top 5 predictions:
# - 21
# - 20
# - 22
# - [unused_punctuation12]
# - 19
#
# Original token: a
# Top 5 predictions:
# - a
# - [unused_punctuation1]
# - [unused_punctuation0]
# - A
# - km
#
# Original token: 33
# Top 5 predictions:
# - 33
# - ##33
# - 32
# - 330
# - 35
#
# Original token: ##45
# Top 5 predictions:
# - ##45
# - ##46
# - ##35
# - ##43
# - ##44
#
# Original token: ##5
# Top 5 predictions:
# - ##5
# - ##6
# - ##4
# - ##0
# - ##3
#
# Original token: Wiesen
# Top 5 predictions:
# - Wiesen
# - Wiese
# - Linden
# - Weiden
# - Blumen
#
# Original token: ##tal
# Top 5 predictions:
# - ##tal
# - ##bad
# - ##feld
# - ##grund
# - ##dorf
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##Berlin
# - [unused_punctuation1]
# - Potsdam
# - [unused_punctuation4]
#
# Original token: ,
# Top 5 predictions:
# - über
# - Unter
# - um
# - An
# - an
#
# Original token: den
# Top 5 predictions:
# - den
# - bis
# - [unused_punctuation0]
# - [unused_punctuation6]
# - [unused_punctuation2]
#
# Original token: 22
# Top 5 predictions:
# - 22
# - 21
# - 20
# - 23
# - 18
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - bis
#
# Original token: 06
# Top 5 predictions:
# - 08
# - 06
# - 05
# - 09
# - 03
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - bis
# - [unused_punctuation1]
# - [unused_punctuation2]
#
# Original token: 20
# Top 5 predictions:
# - 20
# - ##20
# - 21
# - 30
# - 40
#
# Original token: ##32
# Top 5 predictions:
# - ##32
# - ##31
# - ##33
# - ##34
# - ##30
#
# Original token: Sehr
# Top 5 predictions:
# - Sehr
# - Dr
# - Mein
# - sehr
# - Lieber
#
# Original token: geehrt
# Top 5 predictions:
# - geehrt
# - besorgt
# - verehrt
# - Herr
# - freundlich
#
# Original token: ##er
# Top 5 predictions:
# - ##er
# - ##e
# - ##en
# - ##es
# - ##erin
#
# Original token: Herr
# Top 5 predictions:
# - Herr
# - Herrn
# - Frau
# - ##Herr
# - Mann
#
# Original token: Marsch
# Top 5 predictions:
# - Marsch
# - Kn
# - Kl
# - Rad
# - Or
#
# Original token: ##olle
# Top 5 predictions:
# - ##olle
# - ##ole
# - ##le
# - ##alle
# - ##one
#
# Original token: ##k
# Top 5 predictions:
# - ##k
# - ##ks
# - ##ck
# - ##ke
# - ##c
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - [unused_punctuation6]
# - [UNK]
# - [unused_punctuation4]
#
# Original token: wir
# Top 5 predictions:
# - wir
# - Wir
# - Sie
# - sie
# - uns
#
# Original token: berichten
# Top 5 predictions:
# - berichten
# - uns
# - erfahren
# - schreiben
# - Nachrichten
#
# Original token: über
# Top 5 predictions:
# - über
# - von
# - Über
# - darüber
# - zu
#
# Original token: unseren
# Top 5 predictions:
# - unseren
# - ihren
# - meinen
# - Ihren
# - den
#
# Original token: gemeinsamen
# Top 5 predictions:
# - gemeinsamen
# - langjährigen
# - gemeinsame
# - neuen
# - gemeinsames
#
# Original token: Patienten
# Top 5 predictions:
# - Patienten
# - Patient
# - Krebs
# - Kranken
# - Kollegen
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - mit
# - [unused_punctuation6]
# - [unused_punctuation4]
#
# Original token: Herrn
# Top 5 predictions:
# - Herrn
# - Herr
# - [unused_punctuation0]
# - ##en
# - [unused_punctuation4]
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation2]
# - [unused_punctuation17]
# - [unused_punctuation0]
# - Robert
#
# Original token: Ca
# Top 5 predictions:
# - Ca
# - De
# - A
# - Ka
# - de
#
# Original token: ##ja
# Top 5 predictions:
# - ##ja
# - ##ya
# - ##je
# - ##jas
# - ##j
#
# Original token: ##l
# Top 5 predictions:
# - ##l
# - ##la
# - ##ls
# - ##r
# - ##lin
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation2]
# - [unused_punctuation0]
# - Dr
# - L
# - [unused_punctuation1]
#
# Original token: *
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - vom
# - ##a
# - [unused_punctuation7]
#
# Original token: 23
# Top 5 predictions:
# - 23
# - 22
# - 21
# - 24
# - 25
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation6]
# - [unused_punctuation7]
# - bis
#
# Original token: 03
# Top 5 predictions:
# - 03
# - 02
# - 05
# - 04
# - 08
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation1]
# - [UNK]
# - Uhr
#
# Original token: 1968
# Top 5 predictions:
# - 1968
# - [unused_punctuation7]
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [UNK]
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation2]
# - im
# - am
# - [UNK]
#
# Original token: Garten
# Top 5 predictions:
# - Garten
# - Wiesen
# - Wald
# - Natur
# - Park
#
# Original token: ##pf
# Top 5 predictions:
# - ##pf
# - ##spf
# - ##geh
# - ##sp
# - ##aust
#
# Original token: ##ad
# Top 5 predictions:
# - ##ad
# - ##weg
# - ##ade
# - ##ort
# - ##and
#
# Original token: 44
# Top 5 predictions:
# - 44
# - 42
# - 34
# - 41
# - B
#
# Original token: ,
# Top 5 predictions:
# - a
# - [unused_punctuation1]
# - b
# - ##a
# - [unused_punctuation7]
#
# Original token: 33
# Top 5 predictions:
# - 33
# - 32
# - 35
# - ##33
# - 330
#
# Original token: ##45
# Top 5 predictions:
# - ##45
# - ##46
# - ##43
# - ##35
# - ##44
#
# Original token: ##5
# Top 5 predictions:
# - ##5
# - ##6
# - ##4
# - ##3
# - ##0
#
# Original token: Wiesen
# Top 5 predictions:
# - Wiesen
# - Wiese
# - Rosen
# - Eichen
# - Blumen
#
# Original token: ##tal
# Top 5 predictions:
# - ##tal
# - ##dorf
# - ##bad
# - ##bach
# - ##berg
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - Berlin
# - [unused_punctuation5]
# - [UNK]
# - [unused_punctuation4]
#
# Original token: der
# Top 5 predictions:
# - der
# - Der
# - die
# - welcher
# - dieser
#
# Original token: sich
# Top 5 predictions:
# - sich
# - uns
# - mich
# - ##ich
# - bereits
#
# Original token: vom
# Top 5 predictions:
# - vom
# - von
# - Vom
# - im
# - ab
#
# Original token: 20
# Top 5 predictions:
# - 20
# - 22
# - 21
# - 19
# - 18
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - [unused_punctuation6]
# - [unused_punctuation1]
#
# Original token: 08
# Top 5 predictions:
# - 08
# - 05
# - 03
# - 06
# - 07
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation1]
# - [unused_punctuation2]
# - [UNK]
#
# Original token: 20
# Top 5 predictions:
# - 20
# - ##20
# - 21
# - 22
# - 30
#
# Original token: ##32
# Top 5 predictions:
# - ##32
# - ##31
# - ##33
# - ##30
# - ##34
#
# Original token: bis
# Top 5 predictions:
# - bis
# - [unused_punctuation2]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - [unused_punctuation4]
#
# Original token: 22
# Top 5 predictions:
# - 22
# - 20
# - 23
# - 21
# - 18
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - a
# - [unused_punctuation1]
# - [unused_punctuation7]
# - 0
#
# Original token: 08
# Top 5 predictions:
# - 08
# - 05
# - 06
# - 09
# - 07
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - [unused_punctuation1]
# - bis
#
# Original token: 20
# Top 5 predictions:
# - 20
# - ##20
# - 21
# - 40
# - 30
#
# Original token: ##32
# Top 5 predictions:
# - ##32
# - ##31
# - ##34
# - ##33
# - ##35
#
# Original token: in
# Top 5 predictions:
# - in
# - In
# - unter
# - im
# - ##in
#
# Original token: unserer
# Top 5 predictions:
# - unserer
# - meiner
# - der
# - seiner
# - unsere
#
# Original token: stat
# Top 5 predictions:
# - stat
# - fach
# - diagnost
# - klin
# - ambul
#
# Original token: .
# Top 5 predictions:
# - ##ischen
# - ##istischen
# - ##istische
# - ##istischer
# - ##uten
#
# Original token: Behandlung
# Top 5 predictions:
# - Behandlung
# - Klinik
# - Therapie
# - Abteilung
# - Praxis
#
# Original token: befand
# Top 5 predictions:
# - befand
# - befindet
# - befanden
# - befunden
# - hielt
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation4]
# - [unused_punctuation6]
# - mit
#
# Original token: Diagnose
# Top 5 predictions:
# - Diagnose
# - Therapie
# - Symptome
# - diagnost
# - Befund
#
# Original token: ##n
# Top 5 predictions:
# - ##n
# - ##daten
# - ##stellungen
# - ##nr
# - ##en
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation6]
# - von
# - bei
# - der
# - des
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - S
# - H
# - A
#
# Original token: /
# Top 5 predictions:
# - [unused_punctuation0]
# - und
# - [unused_punctuation7]
# - [unused_punctuation13]
# - [unused_punctuation18]
#
# Original token: L
# Top 5 predictions:
# - L
# - B
# - ##L
# - I
# - H
#
# Original token: :
# Top 5 predictions:
# - ##H
# - [unused_punctuation0]
# - ##S
# - [unused_punctuation18]
# - [unused_punctuation1]
#
# Original token: fortgeschritten
# Top 5 predictions:
# - fortgeschritten
# - Intensiv
# - Stadium
# - beginnend
# - ausgeprägt
#
# Original token: ##es
# Top 5 predictions:
# - ##es
# - ##s
# - ##liches
# - ##iertes
# - ##tes
#
# Original token: O
# Top 5 predictions:
# - O
# - A
# - E
# - U
# - R
#
# Original token: ##WG
# Top 5 predictions:
# - ##WG
# - ##G
# - ##W
# - ##hn
# - ##E
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - sowie
# - oder
# - [unused_punctuation9]
#
# Original token: diverse
# Top 5 predictions:
# - diverse
# - verschiedene
# - zahlreiche
# - [unused_punctuation1]
# - diversen
#
# Original token: AT
# Top 5 predictions:
# - AT
# - [unused_punctuation1]
# - A
# - psychische
# - und
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation2]
# - ##B
# - ##S
# - ##A
# - [unused_punctuation7]
#
# Original token: Un
# Top 5 predictions:
# - Un
# - Fehl
# - Rest
# - un
# - An
#
# Original token: ##vert
# Top 5 predictions:
# - ##vert
# - ##vers
# - Vert
# - ##get
# - ##zif
#
# Original token: ##räglichkeit
# Top 5 predictions:
# - ##räglichkeit
# - ##mäßigkeit
# - ##ikationen
# - ##emit
# - ##barkeit
#
# Original token: ##en
# Top 5 predictions:
# - ##en
# - ##n
# - ##störungen
# - ##keiten
# - Beschwerden
#
# Original token: (
# Top 5 predictions:
# - [unused_punctuation1]
# - wie
# - [unused_punctuation4]
# - [unused_punctuation6]
# - von
#
# Original token: z
# Top 5 predictions:
# - z
# - u
# - B
# - [unused_punctuation0]
# - zum
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation6]
# - [UNK]
# - [unused_punctuation1]
# - ##sp
#
# Original token: B
# Top 5 predictions:
# - B
# - A
# - a
# - ##B
# - C
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation6]
# - [UNK]
# - [unused_punctuation5]
# - ##B
#
# Original token: Ta
# Top 5 predictions:
# - Ta
# - Te
# - Sa
# - De
# - He
#
# Original token: ##fl
# Top 5 predictions:
# - ##fl
# - ##pl
# - ##ff
# - ##ph
# - ##kol
#
# Original token: ##ota
# Top 5 predictions:
# - ##ota
# - ##ora
# - ##oko
# - ##ozi
# - ##ita
#
# Original token: ##n
# Top 5 predictions:
# - ##n
# - ##in
# - ##ni
# - ##m
# - ##ns
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - bei
# - mit
#
# Original token: Cos
# Top 5 predictions:
# - Cos
# - Kos
# - Sub
# - Hor
# - Lak
#
# Original token: ##opt
# Top 5 predictions:
# - ##opt
# - ##mo
# - ##art
# - ##min
# - ##oma
#
# Original token: und
# Top 5 predictions:
# - und
# - [unused_punctuation7]
# - ##a
# - [unused_punctuation2]
# - ##in
#
# Original token: Cos
# Top 5 predictions:
# - Cos
# - Kos
# - Wis
# - Sub
# - Ges
#
# Original token: ##opt
# Top 5 predictions:
# - ##opt
# - ##met
# - ##ap
# - ##med
# - ##art
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - ##ik
# - [unused_punctuation0]
# - ##in
#
# Original token: S
# Top 5 predictions:
# - S
# - R
# - L
# - [unused_punctuation7]
# - B
#
# Original token: )
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [UNK]
# - [unused_punctuation1]
# - und
#
# Original token: RA
# Top 5 predictions:
# - RA
# - [unused_punctuation1]
# - R
# - [unused_punctuation4]
# - [unused_punctuation0]
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - und
# - [UNK]
# - ##m
#
# Original token: Z
# Top 5 predictions:
# - Z
# - B
# - ##Z
# - L
# - n
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [UNK]
# - [unused_punctuation7]
# - ##K
# - ##H
#
# Original token: n
# Top 5 predictions:
# - n
# - N
# - J
# - L
# - R
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##g
# - ##m
# - [unused_punctuation2]
# - [UNK]
#
# Original token: N
# Top 5 predictions:
# - N
# - L
# - H
# - O
# - ##N
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - ##J
# - H
# - ##B
# - ##E
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation7]
# - und
# - ##g
# - [unused_punctuation1]
# - [unused_punctuation2]
#
# Original token: Lak
# Top 5 predictions:
# - Lak
# - Mak
# - Mas
# - Hor
# - Kom
#
# Original token: ##o
# Top 5 predictions:
# - ##o
# - ##os
# - ##ose
# - ##a
# - ##io
#
# Original token: bei
# Top 5 predictions:
# - bei
# - beim
# - nach
# - mit
# - [unused_punctuation1]
#
# Original token: Netz
# Top 5 predictions:
# - Netz
# - Glas
# - Horn
# - ##ohr
# - Band
#
# Original token: ##haut
# Top 5 predictions:
# - ##haut
# - ##band
# - ##ohr
# - ##seiten
# - ##gelenk
#
# Original token: ##for
# Top 5 predictions:
# - ##for
# - ##par
# - ##fern
# - ##form
# - ##ver
#
# Original token: ##amen
# Top 5 predictions:
# - ##amen
# - ##en
# - ##änderungen
# - ##am
# - ##ationen
#
# Original token: /
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - Das
# - sowie
# - das
#
# Original token: beginnend
# Top 5 predictions:
# - beginnend
# - begonnen
# - ##ipl
# - eingeleitet
# - abgebrochen
#
# Original token: ##e
# Top 5 predictions:
# - ##e
# - ##es
# - ##em
# - ##s
# - ##er
#
# Original token: Ab
# Top 5 predictions:
# - Ab
# - ab
# - Er
# - Sc
# - Ap
#
# Original token: ##lat
# Top 5 predictions:
# - ##lat
# - ##dat
# - ##las
# - ##ress
# - ##ret
#
# Original token: ##io
# Top 5 predictions:
# - ##io
# - ##ion
# - ##a
# - ##anz
# - ##at
#
# Original token: vor
# Top 5 predictions:
# - vor
# - Vor
# - seit
# - nach
# - in
#
# Original token: 3
# Top 5 predictions:
# - 3
# - 4
# - 2
# - 5
# - 1
#
# Original token: Jahren
# Top 5 predictions:
# - Jahren
# - Jahre
# - Jahr
# - Monaten
# - ##Jahren
#
# Original token: Pro
# Top 5 predictions:
# - Pro
# - ##pro
# - pro
# - Prä
# - Ex
#
# Original token: ##ce
# Top 5 predictions:
# - ##ce
# - ##ze
# - ##ve
# - ##ka
# - ##ca
#
# Original token: ##dere
# Top 5 predictions:
# - ##dere
# - ##du
# - ##um
# - ##zit
# - ##d
#
# Original token: :
# Top 5 predictions:
# - bei
# - und
# - der
# - [unused_punctuation1]
# - [unused_punctuation2]
#
# Original token: Tages
# Top 5 predictions:
# - Tages
# - Blut
# - Lungen
# - Tag
# - Herz
#
# Original token: ##druck
# Top 5 predictions:
# - ##druck
# - ##drucks
# - Druck
# - ##temperatur
# - ##grund
#
# Original token: ##profil
# Top 5 predictions:
# - ##profil
# - ##druck
# - ##bild
# - ##höhen
# - ##volumen
#
# Original token: ##mess
# Top 5 predictions:
# - ##mess
# - ##schein
# - ##kenn
# - ##bild
# - ##maß
#
# Original token: ##ung
# Top 5 predictions:
# - ##ung
# - ##ungen
# - ##ation
# - ##igung
# - ##ion
#
# Original token: +
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - [unused_punctuation7]
# - bei
# - der
#
# Original token: Nacht
# Top 5 predictions:
# - Nacht
# - Tages
# - Lokal
# - Herz
# - Zeit
#
# Original token: ##mess
# Top 5 predictions:
# - ##mess
# - ##kenn
# - ##schein
# - ##maß
# - ##rech
#
# Original token: ##ung
# Top 5 predictions:
# - ##ung
# - ##ungen
# - ##ation
# - ##igung
# - [unused_punctuation1]
#
# Original token: Vis
# Top 5 predictions:
# - Vis
# - Lin
# - vis
# - ##vis
# - Ser
#
# Original token: ##us
# Top 5 predictions:
# - ##us
# - ##a
# - ##D
# - ##um
# - ##ulation
#
# Original token: bei
# Top 5 predictions:
# - bei
# - Bei
# - [unused_punctuation2]
# - [unused_punctuation4]
# - [unused_punctuation1]
#
# Original token: Aufnahme
# Top 5 predictions:
# - Aufnahme
# - Wiederaufnahme
# - aufgenommen
# - Einstellung
# - Entlassung
#
# Original token: :
# Top 5 predictions:
# - von
# - der
# - des
# - mit
# - durch
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - ##R
# - H
# - S
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - ##H
# - ##E
# - ##M
# - ##F
#
# Original token: c
# Top 5 predictions:
# - c
# - b
# - a
# - ##b
# - g
#
# Original token: ##c
# Top 5 predictions:
# - ##c
# - ##b
# - ##d
# - ##r
# - ##ic
#
# Original token: 1
# Top 5 predictions:
# - 1
# - 2
# - 0
# - 3
# - ##1
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - bis
# - [unused_punctuation2]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 5
# - 2
# - 4
#
# Original token: ##pp
# Top 5 predictions:
# - ##pp
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
# - bis
#
# Original token: L
# Top 5 predictions:
# - L
# - R
# - ##L
# - B
# - H
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - ##H
# - [unused_punctuation7]
# - ##M
# - ##m
#
# Original token: c
# Top 5 predictions:
# - c
# - b
# - a
# - ##b
# - g
#
# Original token: ##c
# Top 5 predictions:
# - ##c
# - ##b
# - ##d
# - ##om
# - ##ic
#
# Original token: 1
# Top 5 predictions:
# - 1
# - 2
# - 0
# - ##1
# - 3
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation6]
# - [unused_punctuation2]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 2
# - 5
# - 6
#
# Original token: Vis
# Top 5 predictions:
# - Vis
# - vis
# - ##vis
# - Lin
# - Pass
#
# Original token: ##us
# Top 5 predictions:
# - ##us
# - ##um
# - ##u
# - ##ulation
# - ##a
#
# Original token: bei
# Top 5 predictions:
# - bei
# - [unused_punctuation4]
# - der
# - nach
# - vor
#
# Original token: Entlassung
# Top 5 predictions:
# - Entlassung
# - Aufnahme
# - Wiederaufnahme
# - Behandlung
# - Einstellung
#
# Original token: :
# Top 5 predictions:
# - von
# - der
# - [unused_punctuation1]
# - des
# - nach
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - ##R
# - H
# - S
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - ##H
# - ##E
# - ##N
# - ##U
#
# Original token: c
# Top 5 predictions:
# - c
# - b
# - a
# - ##b
# - g
#
# Original token: ##c
# Top 5 predictions:
# - ##c
# - ##b
# - ##d
# - ##r
# - ##ic
#
# Original token: 1
# Top 5 predictions:
# - 1
# - 2
# - 0
# - 3
# - ##1
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - bis
# - [unused_punctuation2]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - a
# - 2
# - 5
#
# Original token: ##pp
# Top 5 predictions:
# - ##pp
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
# - und
#
# Original token: L
# Top 5 predictions:
# - L
# - R
# - ##L
# - B
# - H
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - ##H
# - ##M
# - [unused_punctuation7]
# - ##U
#
# Original token: c
# Top 5 predictions:
# - c
# - b
# - a
# - ##b
# - g
#
# Original token: ##c
# Top 5 predictions:
# - ##c
# - ##b
# - ##d
# - ##r
# - ##cs
#
# Original token: 1
# Top 5 predictions:
# - 1
# - 2
# - 0
# - 3
# - ##1
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation6]
# - [unused_punctuation2]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 5
# - 2
# - 00
#
# Original token: Ten
# Top 5 predictions:
# - Ten
# - Bis
# - His
# - Port
# - Wach
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - ##sur
# - ##tr
# - ##sen
# - ##zil
#
# Original token: ##io
# Top 5 predictions:
# - ##io
# - ##ion
# - ##ios
# - ##ial
# - ##ius
#
# Original token: bei
# Top 5 predictions:
# - bei
# - Bei
# - [unused_punctuation4]
# - nach
# - beim
#
# Original token: Aufnahme
# Top 5 predictions:
# - Aufnahme
# - Wiederaufnahme
# - der
# - Behandlung
# - Einstellung
#
# Original token: :
# Top 5 predictions:
# - von
# - der
# - des
# - durch
# - [unused_punctuation1]
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - S
# - H
# - T
#
# Original token: :
# Top 5 predictions:
# - ##M
# - [unused_punctuation0]
# - [unused_punctuation18]
# - ##K
# - ##E
#
# Original token: 22
# Top 5 predictions:
# - 22
# - 20
# - 25
# - 18
# - 24
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - ##2
# - ##3
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##y
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##h
# - ##gs
# - ##f
# - ##gen
#
# Original token: L
# Top 5 predictions:
# - L
# - B
# - R
# - [unused_punctuation1]
# - S
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation18]
# - ##H
# - ##K
# - ##M
# - ##E
#
# Original token: 16
# Top 5 predictions:
# - 16
# - 18
# - 20
# - 15
# - 24
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - kg
# - g
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##al
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##gs
# - ##h
# - ##f
# - ##gen
#
# Original token: Ten
# Top 5 predictions:
# - Ten
# - Bis
# - Cre
# - His
# - Cur
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - ##sur
# - ##sen
# - ##sor
# - ##tr
#
# Original token: ##io
# Top 5 predictions:
# - ##io
# - ##ion
# - ##ios
# - ##ial
# - ##ius
#
# Original token: bei
# Top 5 predictions:
# - bei
# - nach
# - Bei
# - [unused_punctuation4]
# - vor
#
# Original token: Entlassung
# Top 5 predictions:
# - Entlassung
# - Aufnahme
# - Wiederaufnahme
# - Einstellung
# - Behandlung
#
# Original token: :
# Top 5 predictions:
# - von
# - der
# - des
# - [unused_punctuation1]
# - nach
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - ##R
# - S
# - B
#
# Original token: :
# Top 5 predictions:
# - ##U
# - ##K
# - ##M
# - ##E
# - [unused_punctuation18]
#
# Original token: 25
# Top 5 predictions:
# - 25
# - 20
# - 22
# - 27
# - 24
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - kg
# - g
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##t
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##h
# - ##gs
# - ##f
# - ##ing
#
# Original token: L
# Top 5 predictions:
# - L
# - B
# - [unused_punctuation1]
# - R
# - S
#
# Original token: :
# Top 5 predictions:
# - ##H
# - [unused_punctuation18]
# - ##K
# - ##E
# - ##S
#
# Original token: 18
# Top 5 predictions:
# - 18
# - 20
# - 22
# - 16
# - 27
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - kg
# - m
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##h
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##gs
# - ##h
# - ##f
# - Erg
#
# Original token: Entlassung
# Top 5 predictions:
# - Entlassung
# - Rehabilitation
# - Aufhebung
# - Abschied
# - Operation
#
# Original token: ##sbe
# Top 5 predictions:
# - ##sbe
# - ##sab
# - ##sver
# - ##s
# - ##ungsbe
#
# Original token: ##fund
# Top 5 predictions:
# - ##fund
# - ##richt
# - ##gin
# - ##fehl
# - ##darf
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation6]
# - ##ung
# - [unused_punctuation1]
# - [UNK]
# - ##s
#
# Original token: Vorder
# Top 5 predictions:
# - Vorder
# - vorder
# - Früher
# - Hinter
# - Front
#
# Original token: ##er
# Top 5 predictions:
# - ##er
# - ##r
# - ##ster
# - ##ter
# - ##erer
#
# Original token: Augen
# Top 5 predictions:
# - Augen
# - Auge
# - Nasen
# - Gesichts
# - Nerven
#
# Original token: ##abschnitt
# Top 5 predictions:
# - ##abschnitt
# - ##strich
# - ##bereich
# - Abschnitt
# - ##abschnitte
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - S
# - [unused_punctuation4]
# - H
#
# Original token: /
# Top 5 predictions:
# - [unused_punctuation0]
# - ##M
# - [unused_punctuation7]
# - ##R
# - ##E
#
# Original token: L
# Top 5 predictions:
# - L
# - B
# - N
# - R
# - M
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation18]
# - ##M
# - ##m
#
# Original token: B
# Top 5 predictions:
# - B
# - A
# - L
# - C
# - D
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##J
# - ##HG
# - [unused_punctuation5]
#
# Original token: rei
# Top 5 predictions:
# - rei
# - l
# - g
# - un
# - ##b
#
# Original token: ##z
# Top 5 predictions:
# - ##z
# - ##ß
# - ##wen
# - ##m
# - ##f
#
# Original token: ##frei
# Top 5 predictions:
# - ##frei
# - ##bar
# - ##fähig
# - [unused_punctuation4]
# - [unused_punctuation1]
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - [unused_punctuation4]
# - mit
# - [unused_punctuation7]
#
# Original token: H
# Top 5 predictions:
# - H
# - ##H
# - I
# - L
# - R
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - ##J
# - ##B
# - ##K
# - ##R
#
# Original token: glatt
# Top 5 predictions:
# - glatt
# - [unused_punctuation1]
# - [unused_punctuation5]
# - [unused_punctuation2]
# - und
#
# Original token: +
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - bis
# - oder
# - [unused_punctuation2]
#
# Original token: klar
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - klar
# - O
# - B
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [UNK]
# - [unused_punctuation0]
# - und
# - [unused_punctuation2]
#
# Original token: V
# Top 5 predictions:
# - V
# - I
# - N
# - E
# - O
#
# Original token: ##K
# Top 5 predictions:
# - ##K
# - ##H
# - ##N
# - ##B
# - ##S
#
# Original token: tief
# Top 5 predictions:
# - tief
# - [unused_punctuation2]
# - ##H
# - [unused_punctuation5]
# - [unused_punctuation7]
#
# Original token: +
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - bis
# - oder
# - [unused_punctuation2]
#
# Original token: leer
# Top 5 predictions:
# - leer
# - [unused_punctuation1]
# - [unused_punctuation0]
# - glatt
# - [unused_punctuation7]
#
# Original token: .
# Top 5 predictions:
# - ##er
# - ##e
# - [unused_punctuation1]
# - ##es
# - ##en
#
# Original token: Cat
# Top 5 predictions:
# - [unused_punctuation1]
# - Cat
# - [unused_punctuation7]
# - und
# - [unused_punctuation2]
#
# Original token: .
# Top 5 predictions:
# - ##t
# - ##e
# - ##s
# - ##h
# - ##ch
#
# Original token: in
# Top 5 predictions:
# - in
# - ex
# - con
# - In
# - per
#
# Original token: ##ci
# Top 5 predictions:
# - ##ci
# - ##cus
# - ##ca
# - ##co
# - ##vis
#
# Original token: ##p
# Top 5 predictions:
# - ##p
# - ##tr
# - ##pat
# - ##per
# - ##pr
#
# Original token: ##iens
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - und
# - [unused_punctuation5]
# - ##us
#
# Original token: Hinter
# Top 5 predictions:
# - Hinter
# - Vorder
# - Äußer
# - Offen
# - vorder
#
# Original token: ##er
# Top 5 predictions:
# - ##er
# - ##en
# - ##r
# - ##ster
# - ##erer
#
# Original token: Augen
# Top 5 predictions:
# - Augen
# - Auge
# - Nasen
# - Gesichts
# - Kopf
#
# Original token: ##abschnitt
# Top 5 predictions:
# - ##abschnitt
# - ##strich
# - ##abschnitte
# - Abschnitt
# - ##streifen
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation4]
# - mit
# - von
# - bei
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - ##R
# - S
# - H
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - ##H
# - [unused_punctuation18]
# - ##K
# - ##E
#
# Original token: N
# Top 5 predictions:
# - N
# - B
# - n
# - C
# - L
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##J
# - ##E
# - ##HS
#
# Original token: an
# Top 5 predictions:
# - an
# - still
# - beid
# - hoch
# - bei
#
# Original token: ##liegend
# Top 5 predictions:
# - ##liegend
# - ##liegende
# - ##kt
# - [unused_punctuation2]
# - ##liegt
#
# Original token: .
# Top 5 predictions:
# - mit
# - [unused_punctuation1]
# - bei
# - und
# - [unused_punctuation5]
#
# Original token: Pap
# Top 5 predictions:
# - Pap
# - ##pap
# - Mam
# - Op
# - Mak
#
# Original token: ##ille
# Top 5 predictions:
# - ##ille
# - ##illa
# - ##el
# - ##ella
# - ##itis
#
# Original token: ra
# Top 5 predictions:
# - ra
# - ta
# - bra
# - ku
# - ü
#
# Original token: ##nd
# Top 5 predictions:
# - ##nd
# - ##nde
# - ##n
# - ##end
# - ##mm
#
# Original token: ##schar
# Top 5 predictions:
# - ##schar
# - ##strei
# - ##stie
# - ##sbe
# - ##kür
#
# Original token: ##f
# Top 5 predictions:
# - ##f
# - ##d
# - ##voll
# - ##ft
# - ##am
#
# Original token: ,
# Top 5 predictions:
# - von
# - [unused_punctuation1]
# - bei
# - mit
# - [unused_punctuation4]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - [unused_punctuation1]
# - 6
# - 2
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - bis
# - [unused_punctuation2]
#
# Original token: 9
# Top 5 predictions:
# - 9
# - 8
# - 7
# - 6
# - 5
#
# Original token: bis
# Top 5 predictions:
# - bis
# - ##bis
# - Bis
# - [unused_punctuation0]
# - [unused_punctuation2]
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 6
# - 2
# - 4
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - [UNK]
# - cm
#
# Original token: 95
# Top 5 predictions:
# - 95
# - 90
# - 50
# - 75
# - 100
#
# Original token: ra
# Top 5 predictions:
# - ra
# - ku
# - ta
# - ste
# - bra
#
# Original token: ##nd
# Top 5 predictions:
# - ##nd
# - ##nde
# - ##n
# - ##st
# - ##nab
#
# Original token: ##ständig
# Top 5 predictions:
# - ##ständig
# - ##ständige
# - ##ig
# - ##voll
# - ##ständigen
#
# Original token: ex
# Top 5 predictions:
# - ex
# - Ex
# - in
# - un
# - ak
#
# Original token: ##ka
# Top 5 predictions:
# - ##ka
# - ##ju
# - ##ta
# - ##ti
# - ##tra
#
# Original token: ##viert
# Top 5 predictions:
# - ##viert
# - ##ct
# - ##ziert
# - ##v
# - ##iert
#
# Original token: ,
# Top 5 predictions:
# - ##e
# - [unused_punctuation1]
# - und
# - [unused_punctuation2]
# - [unused_punctuation7]
#
# Original token: in
# Top 5 predictions:
# - in
# - of
# - In
# - prä
# - trans
#
# Original token: ##fer
# Top 5 predictions:
# - ##fer
# - ##fers
# - ##fen
# - ##fin
# - ##fern
#
# Original token: ##ior
# Top 5 predictions:
# - ##ior
# - [unused_punctuation0]
# - ##ial
# - [unused_punctuation1]
# - [unused_punctuation7]
#
# Original token: Lak
# Top 5 predictions:
# - Lak
# - Sad
# - Mus
# - Kat
# - Col
#
# Original token: ##o
# Top 5 predictions:
# - ##o
# - ##os
# - ##i
# - ##om
# - ##a
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation2]
# - bei
# - mit
# - [unused_punctuation4]
#
# Original token: Her
# Top 5 predictions:
# - Her
# - Rin
# - ##her
# - Sal
# - Hor
#
# Original token: ##de
# Top 5 predictions:
# - ##de
# - ##d
# - ##den
# - ##b
# - ##ge
#
# Original token: um
# Top 5 predictions:
# - um
# - und
# - [unused_punctuation7]
# - [unused_punctuation2]
# - [unused_punctuation1]
#
# Original token: For
# Top 5 predictions:
# - For
# - ##for
# - Bein
# - ##N
# - A
#
# Original token: ##amen
# Top 5 predictions:
# - ##amen
# - ##am
# - ##a
# - ##ame
# - ##at
#
# Original token: mit
# Top 5 predictions:
# - mit
# - [unused_punctuation7]
# - und
# - [unused_punctuation16]
# - [unused_punctuation1]
#
# Original token: Decke
# Top 5 predictions:
# - Decke
# - ##decke
# - Gei
# - Maß
# - Per
#
# Original token: ##l
# Top 5 predictions:
# - ##l
# - ##lung
# - ##r
# - ##t
# - ##li
#
# Original token: .
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - [unused_punctuation2]
# - der
# - [unused_punctuation7]
#
# Original token: Mak
# Top 5 predictions:
# - Mak
# - ##mak
# - Ret
# - Mac
# - ##ch
#
# Original token: ##ula
# Top 5 predictions:
# - ##ula
# - ##a
# - ##una
# - ##ella
# - ##el
#
# Original token: unauf
# Top 5 predictions:
# - unauf
# - un
# - rein
# - rechts
# - end
#
# Original token: ##fällig
# Top 5 predictions:
# - ##fällig
# - ##voll
# - ##hell
# - ##geregt
# - ##gängig
#
# Original token: L
# Top 5 predictions:
# - L
# - R
# - B
# - H
# - D
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation18]
# - ##H
# - ##R
#
# Original token: N
# Top 5 predictions:
# - N
# - n
# - B
# - C
# - L
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - ##J
# - H
# - ##E
# - ##HA
#
# Original token: an
# Top 5 predictions:
# - an
# - end
# - ##an
# - An
# - rechts
#
# Original token: ##liegend
# Top 5 predictions:
# - ##liegend
# - ##liegende
# - [unused_punctuation2]
# - ##fällig
# - ##d
#
# Original token: ,
# Top 5 predictions:
# - mit
# - [unused_punctuation1]
# - und
# - bei
# - [unused_punctuation2]
#
# Original token: Pap
# Top 5 predictions:
# - Pap
# - ##pap
# - Mam
# - Op
# - Mak
#
# Original token: ##ille
# Top 5 predictions:
# - ##ille
# - ##illa
# - ##el
# - ##ella
# - ##itis
#
# Original token: ra
# Top 5 predictions:
# - ra
# - ta
# - ku
# - zü
# - bra
#
# Original token: ##nd
# Top 5 predictions:
# - ##nd
# - ##nde
# - ##mm
# - ##end
# - ##cht
#
# Original token: ##schar
# Top 5 predictions:
# - ##schar
# - ##kür
# - ##strei
# - ##schaft
# - ##sbe
#
# Original token: ##f
# Top 5 predictions:
# - ##f
# - ##fällig
# - ##d
# - ##voll
# - ##ft
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - mit
# - bei
# - und
# - nach
#
# Original token: CD
# Top 5 predictions:
# - CD
# - R
# - L
# - D
# - M
#
# Original token: ##R
# Top 5 predictions:
# - ##R
# - ##D
# - ##S
# - ##K
# - ##N
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 2
# - 6
# - 4
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - bis
#
# Original token: 7
# Top 5 predictions:
# - 7
# - 8
# - 9
# - 6
# - 5
#
# Original token: bis
# Top 5 predictions:
# - bis
# - ##bis
# - Bis
# - [unused_punctuation0]
# - und
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 6
# - 2
# - 4
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - bis
# - [unused_punctuation2]
#
# Original token: 8
# Top 5 predictions:
# - 8
# - 9
# - 7
# - 2
# - 4
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - cm
# - [unused_punctuation5]
# - [unused_punctuation0]
# - [unused_punctuation2]
#
# Original token: Mak
# Top 5 predictions:
# - Mak
# - ##mak
# - ##nit
# - Ret
# - ##ch
#
# Original token: ##ula
# Top 5 predictions:
# - ##ula
# - ##una
# - ##ella
# - ##itis
# - ##ular
#
# Original token: unauf
# Top 5 predictions:
# - unauf
# - un
# - rein
# - schwer
# - irre
#
# Original token: ##fällig
# Top 5 predictions:
# - ##fällig
# - ##voll
# - ##geregt
# - ##band
# - ##wiesen
#
# Original token: Ten
# Top 5 predictions:
# - Ten
# - Rec
# - Par
# - Ok
# - Ut
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - ##ss
# - ##sur
# - ##sor
# - ##tat
#
# Original token: ##ione
# Top 5 predictions:
# - ##ione
# - ##fung
# - ##ci
# - ##ion
# - ##zi
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - ##ss
# - ##en
# - [unused_punctuation4]
# - ##n
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation4]
# - [unused_punctuation2]
# - [unused_punctuation7]
# - der
#
# Original token: RA
# Top 5 predictions:
# - RA
# - [unused_punctuation4]
# - [unused_punctuation1]
# - [UNK]
# - [unused_punctuation0]
#
# Original token: max
# Top 5 predictions:
# - max
# - ##M
# - ##p
# - [unused_punctuation4]
# - [unused_punctuation1]
#
# Original token: 25
# Top 5 predictions:
# - 25
# - 26
# - 20
# - 35
# - 24
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation7]
# - [unused_punctuation2]
# - mm
# - bis
# - ##5
#
# Original token: min
# Top 5 predictions:
# - min
# - bis
# - und
# - [unused_punctuation1]
# - ##m
#
# Original token: 16
# Top 5 predictions:
# - 16
# - 17
# - 18
# - [unused_punctuation7]
# - 20
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - cm
# - [unused_punctuation7]
# - ##mm
# - bis
#
# Original token: im
# Top 5 predictions:
# - im
# - [unused_punctuation7]
# - in
# - Im
# - je
#
# Original token: Mittel
# Top 5 predictions:
# - Mittel
# - Durchschnitt
# - mittel
# - Tief
# - Schnitt
#
# Original token: 20
# Top 5 predictions:
# - 20
# - 15
# - 10
# - 25
# - 18
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - kg
# - ##mo
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##B
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##gs
# - ##h
# - ##f
# - ##d
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - L
# - [unused_punctuation7]
# - [unused_punctuation2]
# - B
#
# Original token: LA
# Top 5 predictions:
# - LA
# - [unused_punctuation1]
# - [UNK]
# - B
# - [unused_punctuation0]
#
# Original token: max
# Top 5 predictions:
# - max
# - maximal
# - ##M
# - [unused_punctuation5]
# - [unused_punctuation4]
#
# Original token: 13
# Top 5 predictions:
# - 13
# - 15
# - 12
# - 14
# - 11
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation7]
# - [unused_punctuation2]
# - mm
# - x
# - ##1
#
# Original token: min
# Top 5 predictions:
# - min
# - bis
# - [unused_punctuation1]
# - ##m
# - und
#
# Original token: 19
# Top 5 predictions:
# - 19
# - 17
# - 20
# - 18
# - 16
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - bis
# - cm
# - [unused_punctuation7]
# - und
#
# Original token: im
# Top 5 predictions:
# - im
# - [unused_punctuation7]
# - Im
# - in
# - je
#
# Original token: Mittel
# Top 5 predictions:
# - Mittel
# - Durchschnitt
# - mittel
# - Extrem
# - Tief
#
# Original token: 15
# Top 5 predictions:
# - 15
# - 20
# - 10
# - 14
# - 13
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - kg
# - cm
# - ##m
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##n
# - ##h
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##h
# - ##gs
# - ##f
# - g
#
# Original token: Pac
# Top 5 predictions:
# - Pac
# - Ent
# - Fein
# - Prä
# - Sub
#
# Original token: ##hy
# Top 5 predictions:
# - ##hy
# - ##so
# - ##to
# - ##hal
# - ##ho
#
# Original token: ##met
# Top 5 predictions:
# - ##met
# - ##let
# - ##th
# - ##ph
# - ##phe
#
# Original token: ##rie
# Top 5 predictions:
# - ##rie
# - ##ie
# - ##r
# - ##omie
# - ##ry
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation1]
# - der
# - [unused_punctuation2]
# - [unused_punctuation4]
# - [UNK]
#
# Original token: RA
# Top 5 predictions:
# - RA
# - [UNK]
# - GA
# - [unused_punctuation0]
# - [unused_punctuation4]
#
# Original token: 49
# Top 5 predictions:
# - 49
# - 50
# - 99
# - 48
# - 51
#
# Original token: ##71
# Top 5 predictions:
# - ##71
# - [unused_punctuation7]
# - ##61
# - ##51
# - ##69
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation17]
# - [unused_punctuation7]
#
# Original token: (
# Top 5 predictions:
# - [UNK]
# - Die
# - [unused_punctuation1]
# - Der
# - [unused_punctuation4]
#
# Original token: Dresdner
# Top 5 predictions:
# - Dresdner
# - Dresden
# - ##er
# - [unused_punctuation1]
# - ##inger
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation2]
# - [unused_punctuation1]
# - Klinik
# - und
# - [unused_punctuation5]
#
# Original token: Korrektur
# Top 5 predictions:
# - Korrektur
# - Reparatur
# - Sanierungs
# - ##in
# - korrig
#
# Original token: +
# Top 5 predictions:
# - ##faktor
# - ##en
# - von
# - [unused_punctuation6]
# - 0
#
# Original token: 2
# Top 5 predictions:
# - 2
# - 3
# - 4
# - 1
# - 0
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - bis
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
#
# Original token: 37
# Top 5 predictions:
# - 37
# - 7
# - 38
# - 35
# - 36
#
# Original token: mm
# Top 5 predictions:
# - mm
# - ##mm
# - cm
# - g
# - kg
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##n
# - ##l
# - ##B
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##h
# - ##gs
# - ##f
# - ##d
#
# Original token: )
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation4]
# - [UNK]
# - bei
#
# Original token: LA
# Top 5 predictions:
# - LA
# - [UNK]
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation17]
#
# Original token: 50
# Top 5 predictions:
# - 50
# - 20
# - 60
# - 100
# - 00
#
# Original token: ##41
# Top 5 predictions:
# - ##41
# - ##40
# - ##61
# - ##60
# - ##51
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation17]
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
#
# Original token: (
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation1]
# - Die
# - Neue
# - der
#
# Original token: Dresdner
# Top 5 predictions:
# - Dresdner
# - Dresden
# - ##er
# - Karlsruher
# - Leipziger
#
# Original token: Korrektur
# Top 5 predictions:
# - Korrektur
# - Reparatur
# - Sanierungs
# - Klinik
# - ##in
#
# Original token: +
# Top 5 predictions:
# - ##en
# - [unused_punctuation6]
# - 0
# - ##faktor
# - [unused_punctuation1]
#
# Original token: 2
# Top 5 predictions:
# - 2
# - 3
# - 4
# - 1
# - 0
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - [unused_punctuation6]
#
# Original token: 01
# Top 5 predictions:
# - 01
# - 00
# - 1
# - 03
# - 04
#
# Original token: ##mm
# Top 5 predictions:
# - ##mm
# - mm
# - ##m
# - m
# - ##mo
#
# Original token: ##H
# Top 5 predictions:
# - ##H
# - H
# - ##l
# - ##B
# - ##y
#
# Original token: ##g
# Top 5 predictions:
# - ##g
# - ##gs
# - ##f
# - ##h
# - [unused_punctuation1]
#
# Original token: )
# Top 5 predictions:
# - L
# - B
# - [unused_punctuation7]
# - N
# - A
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - [unused_punctuation2]
# - [unused_punctuation17]
#
# Original token: Schwellen
# Top 5 predictions:
# - Schwellen
# - Sub
# - Anti
# - Röntgen
# - Micro
#
# Original token: ##per
# Top 5 predictions:
# - ##per
# - Per
# - ##par
# - ##ter
# - per
#
# Original token: ##ime
# Top 5 predictions:
# - ##ime
# - ##imen
# - ##va
# - ##ok
# - ##li
#
# Original token: ##tr
# Top 5 predictions:
# - ##tr
# - ##th
# - ##tal
# - ##kal
# - ##kol
#
# Original token: ##ie
# Top 5 predictions:
# - ##ie
# - ##ien
# - ##ium
# - ##ia
# - ##iem
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation1]
# - [UNK]
# - [unused_punctuation6]
# - der
# - und
#
# Original token: RA
# Top 5 predictions:
# - RA
# - GA
# - [unused_punctuation1]
# - bei
# - [UNK]
#
# Original token: M
# Top 5 predictions:
# - M
# - ##M
# - L
# - B
# - R
#
# Original token: ##D
# Top 5 predictions:
# - ##D
# - ##B
# - ##C
# - ##A
# - ##K
#
# Original token: 4
# Top 5 predictions:
# - 4
# - 6
# - 2
# - 3
# - 5
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation6]
# - [unused_punctuation2]
#
# Original token: 97
# Top 5 predictions:
# - 97
# - 100
# - 98
# - [unused_punctuation7]
# - 95
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [UNK]
# - ##0
# - [unused_punctuation10]
#
# Original token: LA
# Top 5 predictions:
# - LA
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation0]
# - und
#
# Original token: M
# Top 5 predictions:
# - M
# - ##M
# - L
# - B
# - R
#
# Original token: ##D
# Top 5 predictions:
# - ##D
# - ##B
# - ##A
# - ##C
# - ##K
#
# Original token: -
# Top 5 predictions:
# - B
# - ##B
# - ##T
# - [unused_punctuation5]
# - ##Z
#
# Original token: 2
# Top 5 predictions:
# - 2
# - 1
# - 4
# - 3
# - 0
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - bis
#
# Original token: 5
# Top 5 predictions:
# - 5
# - 0
# - ##t
# - 1
# - 25
#
# Original token: Beurteilung
# Top 5 predictions:
# - Beurteilung
# - [unused_punctuation1]
# - [unused_punctuation0]
# - [unused_punctuation5]
# - Beschreibung
#
# Original token: ,
# Top 5 predictions:
# - der
# - von
# - [unused_punctuation1]
# - über
# - in
#
# Original token: Therapie
# Top 5 predictions:
# - Therapie
# - Behandlung
# - Diagnose
# - [unused_punctuation1]
# - ##e
#
# Original token: und
# Top 5 predictions:
# - und
# - ##und
# - [unused_punctuation1]
# - des
# - [unused_punctuation13]
#
# Original token: Verlauf
# Top 5 predictions:
# - Verlauf
# - Zustand
# - Gang
# - Ablauf
# - Beginn
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation6]
# - [unused_punctuation0]
# - [UNK]
# - durch
# - der
#
# Original token: Die
# Top 5 predictions:
# - Die
# - die
# - [unused_punctuation2]
# - [unused_punctuation1]
# - und
#
# Original token: stat
# Top 5 predictions:
# - stat
# - diagnost
# - gen
# - med
# - Röntgen
#
# Original token: .
# Top 5 predictions:
# - ##ische
# - ##ischen
# - ##isch
# - ##istische
# - [unused_punctuation0]
#
# Original token: [SEP]
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - nach
# - 1
# - 2
#
# Original token: [CLS]
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [UNK]
# - und
# - [unused_punctuation4]
#
# Original token: Di
# Top 5 predictions:
# - Di
# - di
# - Hil
# - Ka
# - ##Di
#
# Original token: ##akon
# Top 5 predictions:
# - ##akon
# - ##af
# - ##arm
# - ##äd
# - ##äst
#
# Original token: ##issen
# Top 5 predictions:
# - ##issen
# - ##ie
# - ##ies
# - ##ien
# - ##ischen
#
# Original token: ##kran
# Top 5 predictions:
# - ##kran
# - ##haus
# - ##ken
# - Kranken
# - ##ke
#
# Original token: ##ken
# Top 5 predictions:
# - ##ken
# - ##ke
# - ##k
# - ##en
# - ##ks
#
# Original token: ##haus
# Top 5 predictions:
# - ##haus
# - ##hauses
# - Haus
# - ##ie
# - ##ke
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##n
# - Deutschland
# - Berliner
# - ##s
#
# Original token: [UNK]
# Top 5 predictions:
# - [UNK]
# - [unused_punctuation2]
# - das
# - [unused_punctuation0]
# - [unused_punctuation1]
#
# Original token: Op
# Top 5 predictions:
# - Op
# - In
# - Ne
# - Hyp
# - Di
#
# Original token: ##ht
# Top 5 predictions:
# - ##ht
# - ##ist
# - ##ho
# - ##ät
# - ##hen
#
# Original token: ##hal
# Top 5 predictions:
# - ##hal
# - ##hy
# - ##ho
# - ##her
# - ##hom
#
# Original token: ##mol
# Top 5 predictions:
# - ##mol
# - ##kol
# - ##och
# - ##iol
# - ##men
#
# Original token: ##og
# Top 5 predictions:
# - ##og
# - ##log
# - ##och
# - ##ph
# - ##ut
#
# Original token: ##isches
# Top 5 predictions:
# - ##isches
# - ##isch
# - ##ische
# - ##liches
# - ##ischen
#
# Original token: Zentrum
# Top 5 predictions:
# - Zentrum
# - Institut
# - Krankenhaus
# - ##zentrum
# - Haus
#
# Original token: Di
# Top 5 predictions:
# - Di
# - di
# - Hil
# - ##Di
# - ##di
#
# Original token: ##akon
# Top 5 predictions:
# - ##akon
# - ##af
# - ##vert
# - ##urg
# - ##ich
#
# Original token: ##issen
# Top 5 predictions:
# - ##issen
# - ##ie
# - ##ies
# - ##ien
# - ##ischen
#
# Original token: ##kran
# Top 5 predictions:
# - ##kran
# - ##haus
# - ##ken
# - Kranken
# - ##fach
#
# Original token: ##ken
# Top 5 predictions:
# - ##ken
# - ##ke
# - ##en
# - Kranken
# - ##k
#
# Original token: ##haus
# Top 5 predictions:
# - ##haus
# - ##hauses
# - ##hof
# - Haus
# - ##amt
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - Deutschland
# - ##n
# - Köln
# - ##Berlin
#
# Original token: 122
# Top 5 predictions:
# - 122
# - 12
# - 123
# - 21
# - 120
#
# Original token: ##99
# Top 5 predictions:
# - ##99
# - ##97
# - ##98
# - ##79
# - ##19
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##Berlin
# - Berliner
# - durch
# - Potsdam
#
# Original token: Herrn
# Top 5 predictions:
# - Herrn
# - Herr
# - Den
# - Frau
# - ##Herr
#
# Original token: Dr
# Top 5 predictions:
# - Dr
# - Prof
# - ##Dr
# - Professor
# - Herr
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [UNK]
# - [unused_punctuation2]
# - ##n
# - ##äger
#
# Original token: med
# Top 5 predictions:
# - med
# - Dr
# - Med
# - g
# - jur
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##ias
# - ##icus
# - [UNK]
# - ##ia
#
# Original token: Mike
# Top 5 predictions:
# - Mike
# - Michael
# - Kay
# - Gerald
# - Frank
#
# Original token: Marsch
# Top 5 predictions:
# - Marsch
# - Kl
# - Kn
# - Rad
# - Reg
#
# Original token: ##olle
# Top 5 predictions:
# - ##olle
# - ##ole
# - ##alle
# - ##ale
# - ##one
#
# Original token: ##k
# Top 5 predictions:
# - ##k
# - ##ck
# - ##ke
# - ##n
# - ##ks
#
# Original token: Kant
# Top 5 predictions:
# - Kant
# - Allee
# - Kurfürsten
# - Schön
# - Damm
#
# Original token: ##straße
# Top 5 predictions:
# - ##straße
# - ##str
# - ##allee
# - [unused_punctuation2]
# - ##gasse
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation1]
# - B
# - Straße
# - 21
# - 0
#
# Original token: 21
# Top 5 predictions:
# - 21
# - 20
# - 22
# - [unused_punctuation12]
# - 19
#
# Original token: a
# Top 5 predictions:
# - a
# - [unused_punctuation1]
# - [unused_punctuation0]
# - A
# - km
#
# Original token: 33
# Top 5 predictions:
# - 33
# - ##33
# - 32
# - 330
# - 35
#
# Original token: ##45
# Top 5 predictions:
# - ##45
# - ##46
# - ##35
# - ##43
# - ##44
#
# Original token: ##5
# Top 5 predictions:
# - ##5
# - ##6
# - ##4
# - ##0
# - ##3
#
# Original token: Wiesen
# Top 5 predictions:
# - Wiesen
# - Wiese
# - Linden
# - Weiden
# - Blumen
#
# Original token: ##tal
# Top 5 predictions:
# - ##tal
# - ##bad
# - ##feld
# - ##grund
# - ##dorf
#
# Original token: Berlin
# Top 5 predictions:
# - Berlin
# - ##Berlin
# - [unused_punctuation1]
# - Potsdam
# - [unused_punctuation4]
#
# Original token: ,
# Top 5 predictions:
# - über
# - Unter
# - um
# - An
# - an
#
# Original token: den
# Top 5 predictions:
# - den
# - bis
# - [unused_punctuation0]
# - [unused_punctuation6]
# - [unused_punctuation2]
#
# Original token: 22
# Top 5 predictions:
# - 22
# - 21
# - 20
# - 23
# - 18
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - bis
#
# Original token: 06
# Top 5 predictions:
# - 08
# - 06
# - 05
# - 09
# - 03
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - bis
# - [unused_punctuation1]
# - [unused_punctuation2]
#
# Original token: 20
# Top 5 predictions:
# - 20
# - ##20
# - 21
# - 30
# - 40
#
# Original token: ##32
# Top 5 predictions:
# - ##32
# - ##31
# - ##33
# - ##34
# - ##30
#
# Original token: Sehr
# Top 5 predictions:
# - Sehr
# - Dr
# - Mein
# - sehr
# - Lieber
#
# Original token: geehrt
# Top 5 predictions:
# - geehrt
# - besorgt
# - verehrt
# - Herr
# - freundlich
#
# Original token: ##er
# Top 5 predictions:
# - ##er
# - ##e
# - ##en
# - ##es
# - ##erin
#
# Original token: Herr
# Top 5 predictions:
# - Herr
# - Herrn
# - Frau
# - ##Herr
# - Mann
#
# Original token: Marsch
# Top 5 predictions:
# - Marsch
# - Kn
# - Kl
# - Rad
# - Or
#
# Original token: ##olle
# Top 5 predictions:
# - ##olle
# - ##ole
# - ##le
# - ##alle
# - ##one
#
# Original token: ##k
# Top 5 predictions:
# - ##k
# - ##ks
# - ##ck
# - ##ke
# - ##c
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - und
# - [unused_punctuation6]
# - [UNK]
# - [unused_punctuation4]
#
# Original token: wir
# Top 5 predictions:
# - wir
# - Wir
# - Sie
# - sie
# - uns
#
# Original token: berichten
# Top 5 predictions:
# - berichten
# - uns
# - erfahren
# - schreiben
# ...
# - lokale
# - regionalen
# - stationären
# - örtlichen
#
# Original token: ,
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - oder
# - [unused_punctuation7]
# - sowie
#
# Original token: dr
# Top 5 predictions:
# - dr
# - st
# - r
# - b
# - f
#
# Original token: ##uck
# Top 5 predictions:
# - ##uck
# - ##auch
# - ##ug
# - ##ück
# - ##ruck
#
# Original token: ##sen
# Top 5 predictions:
# - ##sen
# - ##sens
# - ##schen
# - ##se
# - ##san
#
# Original token: ##ken
# Top 5 predictions:
# - ##ken
# - ##den
# - ##ühren
# - ##ifizieren
# - ##dern
#
# Original token: ##den
# Top 5 predictions:
# - ##den
# - ##de
# - ##der
# - ##enden
# - ##ierenden
#
# Original token: Behandlung
# Top 5 predictions:
# - Behandlung
# - Therapie
# - Versorgung
# - Maßnahmen
# - Behandlungs
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation6]
# - ##en
# - und
# - durch
#
# Original token: Regel
# Top 5 predictions:
# - Regel
# - Voll
# - Intensiv
# - Fall
# - Über
#
# Original token: ##mäßige
# Top 5 predictions:
# - ##mäßige
# - ##mäßig
# - regelmäßige
# - ##öse
# - ##mäßigen
#
# Original token: zwischen
# Top 5 predictions:
# - zwischen
# - Zwischen
# - inner
# - über
# - nach
#
# Original token: ##zeitliche
# Top 5 predictions:
# - ##zeitliche
# - ##mäßige
# - ##zeitige
# - regelmäßige
# - ##ordnete
#
# Original token: Ten
# Top 5 predictions:
# - Ten
# - Ly
# - ve
# - Anti
# - Port
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - ##dr
# - ##ss
# - ##tr
# - ##sor
#
# Original token: ##io
# Top 5 predictions:
# - ##io
# - ##ce
# - ##ios
# - ##cin
# - ##co
#
# Original token: -
# Top 5 predictions:
# - [unused_punctuation2]
# - und
# - ##ide
# - [unused_punctuation7]
# - der
#
# Original token: Kontro
# Top 5 predictions:
# - hä
# - Cho
# - ##ska
# - Schwe
# - ##ira
#
# Original token: ##lt
# Top 5 predictions:
# - ##lt
# - ##rt
# - ##lat
# - ##tor
# - ##ld
#
# Original token: ##en
# Top 5 predictions:
# - ##en
# - ##e
# - ##amin
# - ##n
# - ##an
#
# Original token: BA
# Top 5 predictions:
# - BA
# - und
# - [unused_punctuation1]
# - ##werte
# - Werte
#
# Original token: sind
# Top 5 predictions:
# - sind
# - ist
# - [unused_punctuation1]
# - als
# - und
#
# Original token: empfohlen
# Top 5 predictions:
# - empfohlen
# - die
# - empfehlen
# - eine
# - empfiehlt
#
# Original token: .
# Top 5 predictions:
# - ##e
# - die
# - [unused_punctuation0]
# - [unused_punctuation6]
# - zur
#
# Original token: Medik
# Top 5 predictions:
# - Medik
# - ##ament
# - Liquid
# - ##ap
# - Therapie
#
# Original token: ##ation
# Top 5 predictions:
# - ##ation
# - ##ationen
# - ##ament
# - ##ierung
# - ##ate
#
# Original token: :
# Top 5 predictions:
# - mit
# - von
# - durch
# - [unused_punctuation6]
# - der
#
# Original token: R
# Top 5 predictions:
# - R
# - L
# - S
# - H
# - M
#
# Original token: /
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation13]
# - [unused_punctuation2]
# - [unused_punctuation16]
#
# Original token: L
# Top 5 predictions:
# - L
# - B
# - ##L
# - N
# - H
#
# Original token: :
# Top 5 predictions:
# - [unused_punctuation0]
# - und
# - [unused_punctuation2]
# - [unused_punctuation1]
# - [unused_punctuation7]
#
# Original token: Bri
# Top 5 predictions:
# - Bri
# - Anti
# - Mor
# - ##bri
# - Ri
#
# Original token: ##mon
# Top 5 predictions:
# - ##mon
# - ##mat
# - ##min
# - ##um
# - ##mit
#
# Original token: ##idi
# Top 5 predictions:
# - ##idi
# - ##iti
# - ##ici
# - ##id
# - ##ini
#
# Original token: ##n
# Top 5 predictions:
# - ##n
# - ##in
# - ##on
# - ##an
# - ##t
#
# Original token: AT
# Top 5 predictions:
# - AT
# - ##l
# - F
# - G
# - S
#
# Original token: 3
# Top 5 predictions:
# - 3
# - 2
# - 4
# - 5
# - 1
#
# Original token: ##x
# Top 5 predictions:
# - ##x
# - [unused_punctuation1]
# - ##D
# - [unused_punctuation2]
# - ##S
#
# Original token: /
# Top 5 predictions:
# - und
# - [unused_punctuation1]
# - sowie
# - oder
# - durch
#
# Original token: die
# Top 5 predictions:
# - die
# - der
# - Die
# - [unused_punctuation1]
# - eine
#
# Original token: ,
# Top 5 predictions:
# - Kombination
# - Behandlung
# - mit
# - Variante
# - Operation
#
# Original token: Az
# Top 5 predictions:
# - Az
# - Ak
# - Ap
# - Ok
# - Imp
#
# Original token: ##opt
# Top 5 predictions:
# - ##opt
# - ##at
# - ##em
# - ##in
# - ##ut
#
# Original token: AT
# Top 5 predictions:
# - AT
# - ##iat
# - ##at
# - A
# - ##rakt
#
# Original token: 2
# Top 5 predictions:
# - 2
# - 3
# - 4
# - 1
# - ##2
#
# Original token: ##x
# Top 5 predictions:
# - ##x
# - 50
# - [unused_punctuation1]
# - [unused_punctuation2]
# - ##D
#
# Original token: /
# Top 5 predictions:
# - und
# - sowie
# - [unused_punctuation1]
# - oder
# - durch
#
# Original token: die
# Top 5 predictions:
# - die
# - der
# - und
# - [unused_punctuation1]
# - sowie
#
# Original token: ,
# Top 5 predictions:
# - Kombination
# - mit
# - Medikamente
# - Verbindung
# - Variante
#
# Original token: Lu
# Top 5 predictions:
# - Lu
# - ##lu
# - Clo
# - Per
# - ##ala
#
# Original token: ##mi
# Top 5 predictions:
# - ##mi
# - ##ti
# - ##men
# - ##mina
# - ##m
#
# Original token: ##gan
# Top 5 predictions:
# - ##gan
# - ##gin
# - ##g
# - ##x
# - ##d
#
# Original token: 0
# Top 5 predictions:
# - 0
# - 1
# - 2
# - 5
# - 6
#
# Original token: ,
# Top 5 predictions:
# - [unused_punctuation1]
# - ##x
# - [unused_punctuation0]
# - [unused_punctuation2]
# - und
#
# Original token: 1
# Top 5 predictions:
# - 1
# - 0
# - 2
# - 3
# - 9
#
# Original token: %
# Top 5 predictions:
# - ##x
# - [unused_punctuation1]
# - [unused_punctuation2]
# - und
# - oder
#
# Original token: AT
# Top 5 predictions:
# - AT
# - 0
# - [unused_punctuation1]
# - [unused_punctuation0]
# - ##B
#
# Original token: z
# Top 5 predictions:
# - z
# - [unused_punctuation7]
# - B
# - ##Z
# - n
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation7]
# - [unused_punctuation2]
# - ##m
# - ##t
#
# Original token: N
# Top 5 predictions:
# - N
# - n
# - B
# - L
# - P
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation1]
# - und
# - [unused_punctuation5]
# - ##m
#
# Original token: Mit
# Top 5 predictions:
# - Mit
# - mit
# - ##mit
# - ##Mit
# - Sehr
#
# Original token: freundlich
# Top 5 predictions:
# - freundlich
# - Dank
# - gut
# - ruhig
# - ausführlich
#
# Original token: ##en
# Top 5 predictions:
# - ##en
# - und
# - ##e
# - allen
# - ##lichen
#
# Original token: kolle
# Top 5 predictions:
# - kolle
# - sa
# - pa
# - li
# - pla
#
# Original token: ##gi
# Top 5 predictions:
# - ##gi
# - ##gin
# - ##ti
# - ##gs
# - ##ment
#
# Original token: ##alen
# Top 5 predictions:
# - ##alen
# - ##ierten
# - ##alisierten
# - ##al
# - ##alischen
#
# Original token: Grü
# Top 5 predictions:
# - Grü
# - Kä
# - Hel
# - Dank
# - begrü
#
# Original token: ##ßen
# Top 5 predictions:
# - ##ßen
# - ##ssen
# - ##üssen
# - ##issen
# - ##ße
#
# Original token: ,
# Top 5 predictions:
# - von
# - an
# - durch
# - [unused_punctuation6]
# - [unused_punctuation0]
#
# Original token: Prof
# Top 5 predictions:
# - Prof
# - Dr
# - Professor
# - ##Prof
# - ##s
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##D
# - ##R
# - ##es
# - [unused_punctuation1]
#
# Original token: Dr
# Top 5 predictions:
# - Dr
# - Prof
# - Ing
# - ##ärztin
# - Professor
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##ät
# - ##n
# - ##ut
# - ##in
#
# Original token: Ch
# Top 5 predictions:
# - Ch
# - Dr
# - Th
# - P
# - J
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##ula
# - ##un
# - ##yn
# - ##ve
#
# Original token: Jan
# Top 5 predictions:
# - Jan
# - Nie
# - Jacob
# - Lin
# - Fran
#
# Original token: ##ssen
# Top 5 predictions:
# - ##ssen
# - ##sen
# - ##s
# - ##sson
# - ##nen
#
# Original token: Prof
# Top 5 predictions:
# - Prof
# - Dr
# - ##Prof
# - Th
# - [unused_punctuation1]
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - [unused_punctuation6]
# - ##ut
# - ##en
# - ##M
#
# Original token: V
# Top 5 predictions:
# - V
# - v
# - [unused_punctuation2]
# - J
# - T
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##ladimir
# - ##n
# - ##a
# - ##ahl
#
# Original token: Ce
# Top 5 predictions:
# - Ce
# - Bo
# - Ke
# - De
# - The
#
# Original token: ##uster
# Top 5 predictions:
# - ##uster
# - ##uy
# - ##ker
# - ##ckel
# - ##j
#
# Original token: ##s
# Top 5 predictions:
# - ##s
# - [unused_punctuation2]
# - van
# - [unused_punctuation1]
# - und
#
# Original token: J
# Top 5 predictions:
# - J
# - C
# - N
# - B
# - F
#
# Original token: .
# Top 5 predictions:
# - [unused_punctuation0]
# - ##örn
# - ##n
# - ##ns
# - ##ke
#
# Original token: Th
# Top 5 predictions:
# - Th
# - ##Th
# - ##th
# - ##s
# - Ho
#
# Original token: ##iel
# Top 5 predictions:
# - ##iel
# - ##iels
# - ##iele
# - ##ielen
# - ##ies
#
# Original token: Direktor
# Top 5 predictions:
# - Direktor
# - Chef
# - Vizepräsident
# - Ober
# - ##direktor
#
# Original token: ##in
# Top 5 predictions:
# - ##in
# - ##ärztin
# - Präsidentin
# - Frau
# - Leiterin
#
# Original token: der
# Top 5 predictions:
# - der
# - des
# - die
# - ##in
# - von
#
# Original token: Klinik
# Top 5 predictions:
# - Klinik
# - Kliniken
# - ##klinik
# - Krankenhaus
# - Krankenhäuser
#
# Original token: St
# Top 5 predictions:
# - St
# - Ste
# - H
# - Gla
# - Re
#
# Original token: ##v
# Top 5 predictions:
# - ##v
# - [unused_punctuation0]
# - [unused_punctuation2]
# - ##n
# - V
#
# Original token: .
# Top 5 predictions:
# - ##d
# - [unused_punctuation0]
# - ##r
# - [unused_punctuation1]
# - ##g
#
# Original token: Direktor
# Top 5 predictions:
# - Direktor
# - Leiterin
# - ##direktor
# - Chef
# - Senior
#
# Original token: Assistenz
# Top 5 predictions:
# - Assistenz
# - Ober
# - ##in
# - General
# - Chef
#
# Original token: ##ärztin
# Top 5 predictions:
# - ##ärztin
# - ##in
# - ##klinik
# - ##arzt
# - ##medizin
#
# Original token: [SEP]
# Top 5 predictions:
# - [unused_punctuation1]
# - [unused_punctuation0]
# - der
# - und
# - nach
#                        PII_entity       PII_category  PII_start  PII_end  \
# 0   Diakonissenkrankenhaus Berlin  LOCATION_HOSPITAL          0       29
# 1   Diakonissenkrankenhaus Berlin  LOCATION_HOSPITAL         61       90
# 2                           12299       LOCATION_ZIP         91       96
# 3                          Berlin      LOCATION_CITY         97      103
# 4                        Dr. med.         NAME_TITLE        113      121
# 5                Mike Marschollek        NAME_DOCTOR        122      138
# 6                Kantstraße. 21 a    LOCATION_STREET        139      155
# 7                           33455       LOCATION_ZIP        156      161
# 8                       Wiesental      LOCATION_CITY        162      171
# 9                          Berlin      LOCATION_CITY        181      187
# 10                     22.06.2032               DATE        193      203
# 11                    Marschollek        NAME_DOCTOR        224      235
# 12                    Ramón Cajal       NAME_PATIENT        294      305
# 13                     23.03.1968               DATE        308      318
# 14                  Gartenpfad 44    LOCATION_STREET        320      333
# 15                          33455       LOCATION_ZIP        335      340
# 16                      Wiesental      LOCATION_CITY        341      350
# 17                     20.08.2032               DATE        365      375
# 18                     22.08.2032               DATE        380      390
# 19                  Oktober\n2012               DATE       2237     2249
# 20                      Prof. Dr.         NAME_TITLE       2907     2916
# 21                    Ch. Janssen        NAME_DOCTOR       2917     2928
# 22                          Prof.         NAME_TITLE       2929     2934
# 23                    V. Ceusters        NAME_DOCTOR       2935     2946
# 24                       J. Thiel        NAME_DOCTOR       2947     2955
#
#     bert_context_start  bert_context_end  \
# 0                    0              1459
# 1                    0              1459
# 2                    0              1459
# 3                    0              1459
# 4                    0              1459
# 5                    0              1459
# 6                    0              1459
# 7                    0              1459
# 8                    0              1459
# 9                    0              1459
# 10                   0              1459
# 11                   0              1459
# 12                   0              1459
# 13                   0              1459
# 14                   0              1459
# 15                   0              1459
# 16                   0              1459
# 17                   0              1459
# 18                   0              1459
# 19                 989              2788
# 20                1460              3008
# 21                1460              3008
# 22                1460              3008
# 23                1460              3008
# 24                1460              3008
#
#                                PII_tokenized  \
# 0   [1824, 12810, 756, 11853, 412, 691, 715]
# 1   [1824, 12810, 756, 11853, 412, 691, 715]
# 2                              [23331, 1802]
# 3                                      [715]
# 4                 [2682, 26914, 4394, 26914]
# 5                [14104, 17458, 2809, 26917]
# 6              [3686, 1592, 26914, 2439, 18]
# 7                        [3936, 4389, 26957]
# 8                             [13410, 10945]
# 9                                      [715]
# 10    [1389, 26914, 10946, 26914, 148, 5376]
# 11                      [17458, 2809, 26917]
# 12                    [2, 5570, 3171, 26907]
# 13         [1493, 26914, 11417, 26914, 5432]
# 14                    [5383, 334, 227, 6134]
# 15                       [3936, 4389, 26957]
# 16                            [13410, 10945]
# 17     [148, 26914, 10071, 26914, 148, 5376]
# 18    [1389, 26914, 10071, 26914, 148, 5376]
# 19                              [1219, 1338]
# 20                [1850, 26914, 2682, 26914]
# 21                  [528, 26914, 4802, 9781]
# 22                             [1850, 26914]
# 23           [74, 26914, 22833, 4524, 26902]
# 24                   [112, 26914, 1325, 195]
#
#                                      Token_embeddings  \
# 0   [[0.7418668, 0.4263821, -0.46731064, -1.480767...
# 1   [[0.7418668, 0.4263821, -0.46731064, -1.480767...
# 2   [[0.83484375, 0.48591942, 0.39794385, -0.36615...
# 3   [[-0.2692925, 0.041594855, -0.08116214, 0.1158...
# 4   [[0.51936144, 0.3410783, 0.2721948, 0.01096862...
# 5   [[0.9626599, 1.0076388, -0.2985245, 0.15143898...
# 6   [[0.35805866, 1.3763036, 0.41030696, -0.662212...
# 7   [[0.9816525, 1.5218419, 1.4900866, -0.1979038,...
# 8   [[0.41661966, -1.185095, 1.835077, -0.9294547,...
# 9   [[-0.2692925, 0.041594855, -0.08116214, 0.1158...
# 10  [[-0.37940538, 0.7196563, 0.11546316, 0.124406...
# 11  [[1.0802433, 1.413158, 0.93964213, -0.73163384...
# 12  [[0.32129958, 0.8280624, -0.09428098, 1.231800...
# 13  [[0.27127913, 0.6782169, 0.6199562, -0.1150547...
# 14  [[1.3212161, 0.8461088, 0.22860605, 0.07416758...
# 15  [[0.9816525, 1.5218419, 1.4900866, -0.1979038,...
# 16  [[0.41661966, -1.185095, 1.835077, -0.9294547,...
# 17  [[-0.87936956, 0.7803796, 0.06307261, -0.57507...
# 18  [[-0.52584857, 1.323351, 1.0437164, -0.9667705...
# 19  [[0.35066822, 0.013100189, -1.0461848, -1.2330...
# 20  [[1.2341127, 0.51392096, 0.63675094, -0.597653...
# 21  [[1.1604023, 0.20711981, -0.085813455, -0.3994...
# 22  [[1.2341127, 0.51392096, 0.63675094, -0.597653...
# 23  [[1.0660855, 0.2971095, 0.6316138, -0.6381042,...
# 24  [[1.2526505, -0.92597556, -0.28560114, -0.6276...
#
#                                  Token_mean_embedding
# 0   [0.57505125, 0.18170688, 0.2810498, -0.8748777...
# 1   [0.57505125, 0.18170688, 0.2810498, -0.8748777...
# 2   [0.19263326, 0.08091557, 0.13412839, 0.3956380...
# 3   [-0.2692925, 0.041594855, -0.08116214, 0.11581...
# 4   [0.67955905, 0.42792553, 0.3219271, 0.24157222...
# 5   [0.9331897, 0.76209253, 0.24608833, -0.4969524...
# 6   [0.7783621, 1.0022788, 0.5350094, 0.7290001, 0...
# 7   [0.45434082, 0.5332323, 1.0224843, -0.00126563...
# 8   [0.5150715, -0.878658, 1.2125416, -0.67815316,...
# 9   [-0.2692925, 0.041594855, -0.08116214, 0.11581...
# 10  [0.029274324, 0.34469822, -0.04240219, 0.34275...
# 11  [0.9233663, 0.68024373, 0.42762592, -0.7130828...
# 12  [0.58361715, 0.2371014, -0.21655613, 0.5089079...
# 13  [-0.17152569, 0.3366046, 0.2445014, 0.24525532...
# 14  [1.1417382, 1.1566579, 0.16081333, 0.36473745,...
# 15  [0.45434082, 0.5332323, 1.0224843, -0.00126563...
# 16  [0.5150715, -0.878658, 1.2125416, -0.67815316,...
# 17  [-0.3128396, 0.7007036, 0.2941225, -0.3344102,...
# 18  [0.11049358, 1.042857, 0.5601526, -0.13785748,...
# 19  [0.52882725, 0.1800781, -0.47932786, -1.514818...
# 20  [1.0237234, 0.41206142, -0.028386734, -0.61612...
# 21  [0.92136264, 0.19514753, -0.26733413, -0.67679...
# 22  [1.055701, 0.31658766, 0.05069369, -0.4121202,...
# 23  [1.4862111, -0.090550505, 0.17017564, -1.09071...
# 24  [1.2626446, -0.20955679, -0.59231097, -0.74936...

# %%
# Access base BERT model and MLM head
#bert_base = model.bert
mlm_head = model.cls


mean_embedding = torch.tensor(PII_df['Token_mean_embedding'])
mean_embedding = mean_embedding.reshape(1, 25, 768) # Batch size,  tokens, hidden size

# Use the MLM head to get predictions
with torch.no_grad():
    logits = mlm_head(mean_embedding)

# logits shape: (batch_size, sequence_length, vocab_size)
# For each position, get the top 5 predicted tokens
for position in range(logits.size(1)):
    
    position_logits = logits[0, position, :]  # Get logits for this position
    
    # get top 5 logits 
    top_5_indices = torch.topk(position_logits, 5, dim=0).indices
    
    print(f"Top 5 predictions for {PII_df['PII_entity'][position]}:")
    for top_5_indice in top_5_indices:
        token = tokenizer.convert_ids_to_tokens([top_5_indice])[0]
        print(f"  {token}")
    print()
# Out:
# Top 5 predictions for Diakonissenkrankenhaus Berlin:
#   ##haus
#   ##ken
#   ##ie
#   ##ke
#   ##en
#
# Top 5 predictions for Diakonissenkrankenhaus Berlin:
#   ##haus
#   ##ken
#   ##ie
#   ##ke
#   ##en
#
# Top 5 predictions for 12299:
#   ##99
#   ##16
#   ##19
#   122
#   99
#
# Top 5 predictions for Berlin:
#   Berlin
#   ##n
#   Deutschland
#   Berliner
#   ##s
#
# Top 5 predictions for Dr. med.:
#   [unused_punctuation0]
#   Dr
#   med
#   [UNK]
#   [unused_punctuation2]
#
# Top 5 predictions for Mike Marschollek:
#   ##n
#   ##r
#   ##ick
#   ##k
#   ##z
#
# Top 5 predictions for Kantstraße. 21 a:
#   [unused_punctuation1]
#   [unused_punctuation0]
#   21
#   B
#   a
#
# Top 5 predictions for 33455:
#   ##5
#   ##45
#   ##33
#   ##35
#   ##43
#
# Top 5 predictions for Wiesental:
#   Wiesen
#   ##tal
#   ##grün
#   ##weg
#   Wiese
#
# Top 5 predictions for Berlin:
#   Berlin
#   ##n
#   Deutschland
#   Berliner
#   ##s
#
# Top 5 predictions for 22.06.2032:
#   [unused_punctuation0]
#   20
#   22
#   30
#   21
#
# Top 5 predictions for Marschollek:
#   ##n
#   ##ick
#   ##k
#   ##r
#   Marsch
#
# Top 5 predictions for Ramón Cajal:
#   [UNK]
#   ##ja
#   [unused_punctuation0]
#   [unused_punctuation2]
#   de
#
# Top 5 predictions for 23.03.1968:
#   [unused_punctuation0]
#   [unused_punctuation1]
#   [unused_punctuation7]
#   03
#   23
#
# Top 5 predictions for Gartenpfad 44:
#   ##weg
#   ##pf
#   Garten
#   ##r
#   ##m
#
# Top 5 predictions for 33455:
#   ##5
#   ##45
#   ##33
#   ##35
#   ##43
#
# Top 5 predictions for Wiesental:
#   Wiesen
#   ##tal
#   ##grün
#   ##weg
#   Wiese
#
# Top 5 predictions for 20.08.2032:
#   [unused_punctuation0]
#   20
#   22
#   30
#   18
#
# Top 5 predictions for 22.08.2032:
#   22
#   20
#   [unused_punctuation0]
#   30
#   18
#
# Top 5 predictions for Oktober
# 2012:
#   2012
#   Oktober
#   Dezember
#   ##n
#   12
#
# Top 5 predictions for Prof. Dr.:
#   [unused_punctuation0]
#   Dr
#   Prof
#   Professor
#   ##in
#
# Top 5 predictions for Ch. Janssen:
#   Jan
#   [unused_punctuation0]
#   van
#   ##n
#   ##ke
#
# Top 5 predictions for Prof.:
#   [unused_punctuation0]
#   Prof
#   Dr
#   Professor
#   ##R
#
# Top 5 predictions for V. Ceusters:
#   [unused_punctuation0]
#   [unused_punctuation2]
#   ##s
#   van
#   ##n
#
# Top 5 predictions for J. Thiel:
#   [unused_punctuation0]
#   ##n
#   ##ke
#   Th
#   ##iel
# /tmp/ipykernel_2431470/2173982243.py:6: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   mean_embedding = torch.tensor(PII_df['Token_mean_embedding'])

# %%
# for name, module in model.named_children():
#     print(f"{name}: {type(module)}")
    
for name, module in model.named_modules():
    print(f"{name}: {type(module)}")
    
# for param_name, param in model.state_dict().items():
#     print(f"{param_name}: {param.shape}")
    
print(model.config)
print(model.cls)

# for name, param in model.named_parameters():
#     print(f"{name}: requires_grad = {param.requires_grad}")
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-german-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.42.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30000
# }
#
# BertOnlyMLMHead(
#   (predictions): BertLMPredictionHead(
#     (transform): BertPredictionHeadTransform(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (transform_act_fn): GELUActivation()
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     )
#     (decoder): Linear(in_features=768, out_features=30000, bias=True)
#   )
# )
